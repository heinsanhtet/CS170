# %%
# Install packages
# %pip install networkx
# %pip install numpy
# %pip install tqdm
# %pip install matplotlib
# Out:
# Requirement already satisfied: networkx in /srv/conda/envs/notebook/lib/python3.9/site-packages (2.8.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (1.21.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.9/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# The starter code is short and simple, take a look!
from starter import *

# %% [markdown]
# # Phase 1 - Create Inputs

# %%
# Add edges with G.add_edge(u, v, weight=w)
# Idea: consider making the inputs with a solution in mind, 
# such that you know the solution when the outputs are released
import random

def small(G: nx.Graph):
    for i in range(100):
        for j in range(100):
            if i != j:
                G.add_edge(i, j, weight=random.randint(1, 1000))
    
def medium(G: nx.Graph):
    already_in = []
    i = 0
    while i <= 10000:
        rand_v1 = random.randint(0, 299)
        rand_v2 = random.randint(0, 299)
        rand_v = 1000 * rand_v1 + rand_v2
        if rand_v in already_in or rand_v1 == rand_v2:
            continue
        i += 1
        already_in.append(rand_v)
        G.add_edge(rand_v1, rand_v2, weight=random.randint(1, 1000))
        
    
def large(G: nx.Graph):
    already_in = []
    i = 0
    while i <= 10000:
        rand_v1 = random.randint(0, 999)
        rand_v2 = random.randint(0, 999)
        rand_v = 1000 * rand_v1 + rand_v2
        if rand_v in already_in or rand_v1 == rand_v2:
            continue
        i += 1
        already_in.append(rand_v)
        G.add_edge(rand_v1, rand_v2, weight=random.randint(1, 1000))

# %%
G = nx.empty_graph(N_SMALL)
small(G)
write_input(G, 'small.in')

G = nx.empty_graph(N_MEDIUM)
medium(G)
write_input(G, 'medium.in')

G = nx.empty_graph(N_LARGE)
large(G)
write_input(G, 'large.in')

# %% [markdown]
# # Phase 2 - Implement your Solver

# %%
def solve(G: nx.Graph):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']
    
    #random
    for i in range(G.number_of_nodes()):
        G.nodes[i]['team'] = i % 2 + 1
    random_score = score(G)
    
    team_1_list = []
    team_2_list = []
    grouped_vees = []
    max_team_count = G.number_of_nodes() // 2
    sorted_edges = G.edges.data('weight')
    sorted_edges = sorted(sorted_edges, key=lambda x: -x[2])
    for (v1, v2, w) in sorted_edges:
        if len(team_1_list) > max_team_count or len(team_2_list) > max_team_count:
            break
        if v1 in grouped_vees and v2 in grouped_vees: #both already have a group
            continue
        elif v1 in grouped_vees: #v1 is in a group already
            if v1 in team_1_list: #v1 in team1; v2 goes to team2
                G.nodes[v2]['team'] = 2
                team_2_list.append(v2)
                grouped_vees.append(v2)
            else: #v1 in team2, v2 goes to team1
                G.nodes[v2]['team'] = 1
                team_1_list.append(v2)
                grouped_vees.append(v2)
        elif v2 in grouped_vees: #v2 is in a group already
            if v2 in team_1_list: #v2 in team1; v1 goes to team2
                G.nodes[v1]['team'] = 2
                team_2_list.append(v1)
                grouped_vees.append(v1)
            else: #v2 in team2; v1 goes to team1
                G.nodes[v1]['team'] = 1
                team_1_list.append(v2)
                grouped_vees.append(v2)
        else: #both are not in groups yet, can be optimized later
            G.nodes[v1]['team'] = 1
            G.nodes[v2]['team'] = 2
            team_1_list.append(v1)
            team_2_list.append(v2)
            grouped_vees.append(v1)
            grouped_vees.append(v2)
    #do the rest
    for i in range(G.number_of_nodes()):
        if i in grouped_vees:
            continue
        if len(team_1_list) < max_team_count + 1:
            G.nodes[i]['team'] = 1
            team_1_list.append(i)
            grouped_vees.append(i)
        else: 
            G.nodes[i]['team'] = 2
            team_2_list.append(i)
            grouped_vees.append(i)
    wooo_score = score(G)
    if random_score > wooo_score:
        for i in range(G.number_of_nodes()):
            G.nodes[i]['team'] = i % 2 + 1

# %%
G = read_input('small.in')
solve(G)
validate_output(G)
visualize(G)
score(G)
# Out:
# 2389043.7708505495

# %%
run(solve, 'small.in', 'small.out')
# Out:
# small.in: cost 2389043.7708505495

# %%
run_all(solve, 'inputs', 'output')
tar('output')
# Out:
#   0%|          | 0/778 [00:00<?, ?it/s]
# inputs/large1.in: cost 3110292.828182846
# inputs/large10.in: cost 2960119.660390012
# inputs/large100.in: cost 4698272.828182846
# inputs/large101.in: cost 2675988.359807201
# inputs/large102.in: cost 3647698.7708505495
# inputs/large103.in: cost 2497287.828182846
# inputs/large104.in: cost 3847050.359807201
# inputs/large105.in: cost 999272.9322435693
# inputs/large106.in: cost 248508.8281828459
# inputs/large107.in: cost 4943272.93224357
# inputs/large108.in: cost 500272.8281828459
# inputs/large109.in: cost 1747603.8281828458
# inputs/large11.in: cost 989072.828182846
# inputs/large110.in: cost 272.9322435692428
# inputs/large111.in: cost 4345073.113437418
# inputs/large112.in: cost 4738221.563694901
# inputs/large113.in: cost 1890554.1350622333
# inputs/large114.in: cost 1.2868960883071808e+21
# inputs/large115.in: cost 872.9322435692428
# inputs/large116.in: cost 490272.8281828459
# inputs/large117.in: cost 996275.9322435693
# inputs/large118.in: cost 2483156.828182846
# inputs/large119.in: cost 1663217.8281828458
# inputs/large12.in: cost 2250353.828182846
# inputs/large120.in: cost 900272.828182846
# inputs/large121.in: cost 495272.8281828459
# inputs/large122.in: cost 480272.8281828459
# inputs/large123.in: cost 2537773.828182846
# inputs/large124.in: cost 3346386.828182846
# inputs/large125.in: cost 375022.8281828459
# inputs/large126.in: cost 362539.8281828459
# inputs/large127.in: cost 677939.828182846
# inputs/large128.in: cost 267222.8281828459
# inputs/large129.in: cost 915072.828182846
# inputs/large13.in: cost 498172.93224356923
# inputs/large130.in: cost 2454064.5920076068
# inputs/large131.in: cost 2528272.9322435693
# inputs/large132.in: cost 2414343.519281397
# inputs/large133.in: cost 240706.8281828459
# inputs/large134.in: cost 2674129.828182846
# inputs/large135.in: cost 2726871.828182846
# inputs/large136.in: cost 850472.1053050368
# inputs/large137.in: cost 1339990.8281828458
# inputs/large138.in: cost 2748421.917958774
# inputs/large139.in: cost 252993.8281828459
# inputs/large14.in: cost 249867.8281828459
# inputs/large140.in: cost 3242025.63146289
# inputs/large141.in: cost 245664.8281828459
# inputs/large142.in: cost 4950322.828182846
# inputs/large143.in: cost 245565.8281828459
# inputs/large144.in: cost 1935893.5408038984
# inputs/large145.in: cost 205022.8281828459
# inputs/large146.in: cost 2249001.077787128
# inputs/large147.in: cost 2503771.828182846
# inputs/large148.in: cost 1240272.8281828458
# inputs/large149.in: cost 1773272.9322435693
# inputs/large15.in: cost 243559.8281828459
# inputs/large150.in: cost 3230851.1761919903
# inputs/large151.in: cost 2041113.1184461056
# inputs/large152.in: cost 518814.8281828459
# inputs/large153.in: cost 148551923.1505594
# inputs/large154.in: cost 434272.93224356923
# inputs/large155.in: cost 4073650.7297283025
# inputs/large156.in: cost 500272.93224356923
# inputs/large157.in: cost 1444137.359807201
# inputs/large158.in: cost 1045976.772757338
# inputs/large159.in: cost 615006.7856550649
# inputs/large16.in: cost 748772.828182846
# inputs/large160.in: cost 3963272.9322435693
# inputs/large161.in: cost 1077535.8281828458
# inputs/large162.in: cost 5177272.828182846
# inputs/large163.in: cost 2465610.828182846
# inputs/large164.in: cost 3098491.828182846
# inputs/large165.in: cost 2477614.828182846
# inputs/large166.in: cost 1734722.8281828458
# inputs/large167.in: cost 2743698.917958774
# inputs/large168.in: cost 1208967.0394318756
# inputs/large169.in: cost 2977680.1184461056
# inputs/large17.in: cost 2684284.815063163
# inputs/large170.in: cost 484956.8281828459
# inputs/large171.in: cost 500272.8281828459
# inputs/large172.in: cost 827919.0200966783
# inputs/large173.in: cost 255076.8281828459
# inputs/large174.in: cost 2536496.7297283025
# inputs/large175.in: cost 2411439.6647359324
# inputs/large176.in: cost 711449.828182846
# inputs/large177.in: cost 429444.25669257535
# inputs/large178.in: cost 249140.8281828459
# inputs/large18.in: cost 2561962.828182846
# inputs/large180.in: cost 2916423.828182846
# inputs/large181.in: cost 4895372.828182846
# inputs/large182.in: cost 4615806.196497108
# inputs/large183.in: cost 2390272.9322435693
# inputs/large184.in: cost 998272.828182846
# inputs/large185.in: cost 2506692.828182846
# inputs/large186.in: cost 1376420.8281828458
# inputs/large187.in: cost 2752387.0200966783
# inputs/large188.in: cost 1005295.4802612247
# inputs/large189.in: cost 384418.8281828459
# inputs/large19.in: cost 3479531.828182846
# inputs/large190.in: cost 4222102.828182846
# inputs/large191.in: cost 643075.1084976427
# inputs/large192.in: cost 2774622.828182846
# inputs/large193.in: cost 253885.8281828459
# inputs/large194.in: cost 492302.8281828459
# inputs/large195.in: cost 2480435.828182846
# inputs/large196.in: cost 2505631.917958774
# inputs/large197.in: cost 1824594.8281828458
# inputs/large198.in: cost 3175729.3331243102
# inputs/large199.in: cost 1245995.8281828458
# inputs/large2.in: cost 4521888.828182846
# inputs/large20.in: cost 1107335.8281828458
# inputs/large200.in: cost 1123772.8281828458
# inputs/large201.in: cost 1283843.8281828458
# inputs/large202.in: cost 3262561.43727845
# inputs/large203.in: cost 998272.828182846
# inputs/large204.in: cost 273742.8281828459
# inputs/large205.in: cost 2540329.828182846
# inputs/large206.in: cost 133842280.518954
# inputs/large207.in: cost 278100.68377457955
# inputs/large208.in: cost 297403.8281828459
# inputs/large209.in: cost 117048.81650486989
# inputs/large21.in: cost 242381.8281828459
# inputs/large210.in: cost 370790.93342722824
# inputs/large211.in: cost 4883089.828182846
# inputs/large212.in: cost 2076383.1093870206
# inputs/large213.in: cost 5269374.828182846
# inputs/large214.in: cost 3702852.828182846
# inputs/large215.in: cost 1891051.5612341
# inputs/large216.in: cost 200272.8281828459
# inputs/large217.in: cost 2734111.196497107
# inputs/large218.in: cost 272.8281828459045
# inputs/large219.in: cost 3880961.196497107
# inputs/large22.in: cost 585430.1184461056
# inputs/large220.in: cost 2788720.0200966783
# inputs/large221.in: cost 1826525.8281828458
# inputs/large222.in: cost 4475272.828182846
# inputs/large223.in: cost 497206.8281828459
# inputs/large224.in: cost 1440417.8281828458
# inputs/large225.in: cost 230779.8281828459
# inputs/large226.in: cost 323644.8281828459
# inputs/large227.in: cost 278943.8281828459
# inputs/large228.in: cost 593634.6465467927
# inputs/large229.in: cost 272.8281828459045
# inputs/large23.in: cost 487400.8281828459
# inputs/large230.in: cost 167105.8281828459
# inputs/large231.in: cost 468410.7083897999
# inputs/large232.in: cost 1072776.8281828458
# inputs/large233.in: cost 2553020.828182846
# inputs/large234.in: cost 4720249.917958775
# inputs/large235.in: cost 748272.9322435693
# inputs/large236.in: cost 307517.8281828459
# inputs/large237.in: cost 2507423.828182846
# inputs/large238.in: cost 250180.8281828459
# inputs/large239.in: cost 296609.8281828459
# inputs/large24.in: cost 2821746.828182846
# inputs/large240.in: cost 2583912.828182846
# inputs/large241.in: cost 410053.8281828459
# inputs/large242.in: cost 2457820.828182846
# inputs/large243.in: cost 513872.8281828459
# inputs/large244.in: cost 1262784.8281828458
# inputs/large245.in: cost 246632.8281828459
# inputs/large246.in: cost 290637.8281828459
# inputs/large247.in: cost 1254588.5612341003
# inputs/large248.in: cost 2645736.828182846
# inputs/large249.in: cost 1172.8281828459044
# inputs/large25.in: cost 519291.8281828459
# inputs/large250.in: cost 2980941.933427228
# inputs/large251.in: cost 438697.91795877425
# inputs/large252.in: cost 2927801.1761919903
# inputs/large253.in: cost 2407765.8569634487
# inputs/large254.in: cost 2866428.917958774
# inputs/large255.in: cost 1689364.8281828458
# inputs/large256.in: cost 3981272.9322435693
# inputs/large257.in: cost 2883543.1134374174
# inputs/large258.in: cost 4910272.828182846
# inputs/large259.in: cost 2527745.828182846
# inputs/large26.in: cost 4055732.7100717844
# inputs/large260.in: cost 4120852.540803898
# inputs/large27.in: cost 2542086.828182846
# inputs/large28.in: cost 748610.828182846
# inputs/large29.in: cost 2698740.828182846
# inputs/large3.in: cost 4055272.9322435693
# inputs/large30.in: cost 2570311.828182846
# inputs/large31.in: cost 855491.828182846
# inputs/large32.in: cost 500777.8281828459
# inputs/large33.in: cost 4977272.828182846
# inputs/large34.in: cost 3899918.196497107
# inputs/large35.in: cost 1649038.1702989875
# inputs/large36.in: cost 240272.8281828459
# inputs/large37.in: cost 1049467.8281828458
# inputs/large38.in: cost 846177.828182846
# inputs/large39.in: cost 265494.8281828459
# inputs/large4.in: cost 4757677.828182846
# inputs/large40.in: cost 7681872.93224357
# inputs/large41.in: cost 272.8281828459045
# inputs/large42.in: cost 41616807575.640816
# inputs/large43.in: cost 500272.8281828459
# inputs/large44.in: cost 261265.8281828459
# inputs/large45.in: cost 250772.93224356923
# inputs/large46.in: cost 500272.8281828459
# inputs/large47.in: cost 4950272.828182846
# inputs/large48.in: cost 2512408.828182846
# inputs/large49.in: cost 2509774.828182846
# inputs/large5.in: cost 1026373.828182846
# inputs/large50.in: cost 1195375.8281828458
# inputs/large51.in: cost 301089.8281828459
# inputs/large52.in: cost 2484294.7297283025
# inputs/large53.in: cost 272.8281828459045
# inputs/large54.in: cost 1245151.8281828458
# inputs/large55.in: cost 1821021.8281828458
# inputs/large56.in: cost 2482911.828182846
# inputs/large57.in: cost 1060530.8281828458
# inputs/large58.in: cost 500272.8281828459
# inputs/large59.in: cost 507252.93224356923
# inputs/large6.in: cost 329011.8281828459
# inputs/large60.in: cost 499272.8281828459
# inputs/large61.in: cost 1256654.8281828458
# inputs/large62.in: cost 2473892.828182846
# inputs/large63.in: cost 1764956.8281828458
# inputs/large64.in: cost 2700609.828182846
# inputs/large65.in: cost 736313.3331243102
# inputs/large66.in: cost 4970272.828182846
# inputs/large67.in: cost 4282952.113437417
# inputs/large68.in: cost 699825.828182846
# inputs/large69.in: cost 272.8281828459045
# inputs/large7.in: cost 3671648.0394318756
# inputs/large70.in: cost 272.9322435692428
# inputs/large71.in: cost 3749368.828182846
# inputs/large72.in: cost 413191.8281828459
# inputs/large73.in: cost 2300607.596443101
# inputs/large74.in: cost 2075741.8281828458
# inputs/large75.in: cost 5017272.93224357
# inputs/large76.in: cost 368934.8281828459
# inputs/large77.in: cost 304983.8281828459
# inputs/large78.in: cost 830272.828182846
# inputs/large79.in: cost 5035274.265638047
# inputs/large8.in: cost 2492612.056605223
# inputs/large80.in: cost 1528037.8281828458
# inputs/large81.in: cost 251122.93224356923
# inputs/large82.in: cost 2595880.828182846
# inputs/large83.in: cost 272.8281828459045
# inputs/large84.in: cost 4898740.93224357
# inputs/large85.in: cost 720272.828182846
# inputs/large86.in: cost 2822788.1093870206
# inputs/large87.in: cost 4356035.828182846
# inputs/large88.in: cost 2683049.828182846
# inputs/large89.in: cost 2000348.8281828458
# inputs/large9.in: cost 2558567.828182846
# inputs/large90.in: cost 949058.828182846
# inputs/large91.in: cost 260504.8281828459
# inputs/large92.in: cost 2429302.828182846
# inputs/large93.in: cost 1140372.1184461056
# inputs/large94.in: cost 4970272.828182846
# inputs/large95.in: cost 3136509.828182846
# inputs/large96.in: cost 440222921.270409
# inputs/large97.in: cost 570272.828182846
# inputs/large98.in: cost 251092.8281828459
# inputs/large99.in: cost 272.9322435692428
# inputs/medium1.in: cost 3468942.135062233
# inputs/medium10.in: cost 3131815.996532662
# inputs/medium100.in: cost 4470272.828182846
# inputs/medium101.in: cost 2805784.550386777
# inputs/medium102.in: cost 2214958.909281996
# inputs/medium103.in: cost 482356.7333698331
# inputs/medium104.in: cost 3536263.8099124203
# inputs/medium105.in: cost 272.8281828459045
# inputs/medium106.in: cost 255972.3371690421
# inputs/medium107.in: cost 2808273.219127557
# inputs/medium108.in: cost 3475870.7708505495
# inputs/medium109.in: cost 438925.8281828459
# inputs/medium11.in: cost 2233772.828182846
# inputs/medium110.in: cost 2401273.219127557
# inputs/medium111.in: cost 3457765.733369833
# inputs/medium112.in: cost 2564776.550386777
# inputs/medium113.in: cost 2370890.828182846
# inputs/medium114.in: cost 2.1902513963787427e+17
# inputs/medium115.in: cost 257875.57135214296
# inputs/medium116.in: cost 342273.219127557
# inputs/medium117.in: cost 593679.219127557
# inputs/medium118.in: cost 2499079.828182846
# inputs/medium119.in: cost 571549.219127557
# inputs/medium12.in: cost 2455977.733369833
# inputs/medium120.in: cost 3745233.828182846
# inputs/medium121.in: cost 4050272.828182846
# inputs/medium122.in: cost 268472.8281828459
# inputs/medium123.in: cost 496508.219127557
# inputs/medium124.in: cost 3254358.909281996
# inputs/medium125.in: cost 7904751039485.736
# inputs/medium126.in: cost 473348.80991242034
# inputs/medium127.in: cost 2372244.828182846
# inputs/medium128.in: cost 259262.8281828459
# inputs/medium129.in: cost 1104272.8281828458
# inputs/medium13.in: cost 2584177.828182846
# inputs/medium130.in: cost 352372.8281828459
# inputs/medium131.in: cost 6720789.219127557
# inputs/medium132.in: cost 2568506.828182846
# inputs/medium133.in: cost 11820791.466684798
# inputs/medium134.in: cost 2513485.828182846
# inputs/medium135.in: cost 2421837.0120528056
# inputs/medium136.in: cost 1005252.597282364
# inputs/medium137.in: cost 2841595.0200966783
# inputs/medium138.in: cost 2131512.733369833
# inputs/medium139.in: cost 559552.828182846
# inputs/medium14.in: cost 252725.8281828459
# inputs/medium140.in: cost 3204249.8736800537
# inputs/medium141.in: cost 202700.13506223334
# inputs/medium142.in: cost 741527.828182846
# inputs/medium143.in: cost 2217951.621932212
# inputs/medium144.in: cost 1669623.9092819963
# inputs/medium145.in: cost 3.068830528054997e+18
# inputs/medium146.in: cost 689399.2506811945
# inputs/medium147.in: cost 2494685.828182846
# inputs/medium148.in: cost 1282772.8281828458
# inputs/medium149.in: cost 1034272.828182846
# inputs/medium15.in: cost 1253988.7708505495
# inputs/medium150.in: cost 3117749.0200966783
# inputs/medium151.in: cost 2473568.762910035
# inputs/medium152.in: cost 380366.8281828459
# inputs/medium153.in: cost 549612.8736800536
# inputs/medium154.in: cost 434273.219127557
# inputs/medium155.in: cost 3080220.8736800537
# inputs/medium156.in: cost 1551836470707355.2
# inputs/medium157.in: cost 605399.1237506395
# inputs/medium158.in: cost 325272.8281828459
# inputs/medium159.in: cost 758324.9179587744
# inputs/medium16.in: cost 253572.8281828459
# inputs/medium160.in: cost 1400272.8281828458
# inputs/medium161.in: cost 1169412.9179587744
# inputs/medium162.in: cost 1516272.8281828458
# inputs/medium163.in: cost 2365647.828182846
# inputs/medium164.in: cost 2774913.828182846
# inputs/medium165.in: cost 2263592.2506811945
# inputs/medium166.in: cost 1525238.9362576168
# inputs/medium167.in: cost 2727541.8099124203
# inputs/medium168.in: cost 2292184.7708505495
# inputs/medium169.in: cost 2499889.135062233
# inputs/medium17.in: cost 4445108.190073396
# inputs/medium170.in: cost 1647321.0200966783
# inputs/medium171.in: cost 374672.8281828459
# inputs/medium172.in: cost 580547.828182846
# inputs/medium173.in: cost 235765.8281828459
# inputs/medium174.in: cost 2867167.996532662
# inputs/medium175.in: cost 2036650.0200966783
# inputs/medium176.in: cost 631272.8394992325
# inputs/medium177.in: cost 408704.8281828459
# inputs/medium178.in: cost 249061.64799509366
# inputs/medium18.in: cost 2192273.7708505495
# inputs/medium180.in: cost 877998.3371690421
# inputs/medium181.in: cost 2797472.828182846
# inputs/medium182.in: cost 3996675.597282364
# inputs/medium183.in: cost 2861273.219127557
# inputs/medium184.in: cost 196773.21912755698
# inputs/medium185.in: cost 2507470.828182846
# inputs/medium186.in: cost 1279325.8281828458
# inputs/medium187.in: cost 2968827.996532662
# inputs/medium188.in: cost 480903.8281828459
# inputs/medium189.in: cost 636818.5503867774
# inputs/medium19.in: cost 3272734.828182846
# inputs/medium190.in: cost 4223963.337169042
# inputs/medium191.in: cost 11084336.466684798
# inputs/medium192.in: cost 1909773.219127557
# inputs/medium193.in: cost 265338.2982960318
# inputs/medium194.in: cost 648697.8099124203
# inputs/medium195.in: cost 3928318.909281996
# inputs/medium196.in: cost 2368244.135062233
# inputs/medium197.in: cost 2008577.8281828458
# inputs/medium198.in: cost 3567969.8099124203
# inputs/medium199.in: cost 1323690.9092819963
# inputs/medium2.in: cost 4441844.337169043
# inputs/medium20.in: cost 921893.828182846
# inputs/medium200.in: cost 797792.828182846
# inputs/medium201.in: cost 2400916.603742123
# inputs/medium202.in: cost 3089608.187521875
# inputs/medium203.in: cost 3330610.996532662
# inputs/medium204.in: cost 260700.8281828459
# inputs/medium205.in: cost 2335436.550386777
# inputs/medium206.in: cost 5756013.832626473
# inputs/medium207.in: cost 326335.7333698331
# inputs/medium208.in: cost 323866.8281828459
# inputs/medium209.in: cost 2954355.828182846
# inputs/medium21.in: cost 308491.7333698331
# inputs/medium210.in: cost 4131171.452539502
# inputs/medium211.in: cost 268965.8281828459
# inputs/medium212.in: cost 1926350.0200966783
# inputs/medium213.in: cost 2928386.0200966783
# inputs/medium214.in: cost 367072.8281828459
# inputs/medium215.in: cost 1430604.8281828458
# inputs/medium216.in: cost 3045272.828182846
# inputs/medium217.in: cost 2334122.123750639
# inputs/medium218.in: cost 261273.21912755698
# inputs/medium219.in: cost 3687182.550386777
# inputs/medium22.in: cost 434782.80991242034
# inputs/medium220.in: cost 1682286.337169042
# inputs/medium221.in: cost 2540298.0200966783
# inputs/medium222.in: cost 4260272.828182846
# inputs/medium223.in: cost 2910241.9607293718
# inputs/medium224.in: cost 802958.828182846
# inputs/medium225.in: cost 236483.8281828459
# inputs/medium226.in: cost 1408438.1875218751
# inputs/medium227.in: cost 298272.8281828459
# inputs/medium228.in: cost 255936.8281828459
# inputs/medium229.in: cost 3335.219127556996
# inputs/medium23.in: cost 476395.8281828459
# inputs/medium230.in: cost 352388.219127557
# inputs/medium231.in: cost 253519.8281828459
# inputs/medium232.in: cost 512713.80991242034
# inputs/medium233.in: cost 2657067.733369833
# inputs/medium234.in: cost 4258276.828182846
# inputs/medium235.in: cost 445273.219127557
# inputs/medium236.in: cost 305696.8281828459
# inputs/medium237.in: cost 2135760.828182846
# inputs/medium238.in: cost 327623.7333698331
# inputs/medium239.in: cost 608157.0200966783
# inputs/medium24.in: cost 2545126.135062233
# inputs/medium240.in: cost 2442563.828182846
# inputs/medium241.in: cost 4110392.187521875
# inputs/medium242.in: cost 2551712.828182846
# inputs/medium243.in: cost 290656402.94464886
# inputs/medium244.in: cost 1392366.7708505495
# inputs/medium245.in: cost 11413536.466684798
# inputs/medium246.in: cost 296934.8281828459
# inputs/medium247.in: cost 6293763.832626473
# inputs/medium248.in: cost 3263941.996532662
# inputs/medium249.in: cost 230532.8281828459
# inputs/medium25.in: cost 594902.9179587743
# inputs/medium250.in: cost 3459397.996532662
# inputs/medium251.in: cost 395785.13506223337
# inputs/medium252.in: cost 2507331.8433485385
# inputs/medium253.in: cost 2286526.187521875
# inputs/medium254.in: cost 913576.7333698331
# inputs/medium255.in: cost 5918758.452539502
# inputs/medium256.in: cost 290272.8281828459
# inputs/medium257.in: cost 2799150.0120528056
# inputs/medium258.in: cost 2.2551231098425518e+21
# inputs/medium259.in: cost 2339482.828182846
# inputs/medium26.in: cost 2615836.917958774
# inputs/medium260.in: cost 2377963.190073396
# inputs/medium27.in: cost 2594055.337169042
# inputs/medium28.in: cost 2477967.8099124203
# inputs/medium29.in: cost 4480013.996532662
# inputs/medium3.in: cost 4156273.219127557
# inputs/medium30.in: cost 2474516.828182846
# inputs/medium31.in: cost 1352846.9965326618
# inputs/medium32.in: cost 2790272.828182846
# inputs/medium33.in: cost 4451272.828182846
# inputs/medium34.in: cost 3798050.550386777
# inputs/medium35.in: cost 566707.9092819963
# inputs/medium36.in: cost 3273873.219127557
# inputs/medium37.in: cost 1855067.0200966783
# inputs/medium38.in: cost 548967.8394992325
# inputs/medium39.in: cost 589797.0200966783
# inputs/medium4.in: cost 7367583.832626473
# inputs/medium40.in: cost 6295473.219127557
# inputs/medium41.in: cost 273.2191275569962
# inputs/medium42.in: cost 4845273.219127557
# inputs/medium43.in: cost 552851412.1605905
# inputs/medium44.in: cost 3191162.6219322113
# inputs/medium45.in: cost 3528272.828182846
# inputs/medium46.in: cost 254272.8281828459
# inputs/medium47.in: cost 1450272.8281828458
# inputs/medium48.in: cost 2330412.828182846
# inputs/medium49.in: cost 2301675.187521875
# inputs/medium5.in: cost 396999.3371690421
# inputs/medium50.in: cost 788272.828182846
# inputs/medium51.in: cost 463335.80991242034
# inputs/medium52.in: cost 3092033.597282364
# inputs/medium53.in: cost 250272.8281828459
# inputs/medium54.in: cost 1264038.9092819963
# inputs/medium55.in: cost 1762361.8736800535
# inputs/medium56.in: cost 1550392.8281828458
# inputs/medium57.in: cost 501862.18752187514
# inputs/medium58.in: cost 224273.21912755698
# inputs/medium59.in: cost 2915448.733369833
# inputs/medium6.in: cost 273922.8281828459
# inputs/medium60.in: cost 4340272.828182846
# inputs/medium61.in: cost 1093799.8281828458
# inputs/medium62.in: cost 2510715.0120528056
# inputs/medium63.in: cost 758058.5503867774
# inputs/medium64.in: cost 1523109.8099124203
# inputs/medium65.in: cost 1131023.597282364
# inputs/medium66.in: cost 4260272.828182846
# inputs/medium67.in: cost 4040894.909281996
# inputs/medium68.in: cost 1233450.733369833
# inputs/medium69.in: cost 252272.8281828459
# inputs/medium7.in: cost 3665436.187521875
# inputs/medium70.in: cost 220273.21912755698
# inputs/medium71.in: cost 3728900.828182846
# inputs/medium72.in: cost 272268.9092819963
# inputs/medium73.in: cost 2696884.8099124203
# inputs/medium74.in: cost 2128185.733369833
# inputs/medium75.in: cost 4991272.828182846
# inputs/medium76.in: cost 1239259.9179587741
# inputs/medium77.in: cost 263276.8281828459
# inputs/medium78.in: cost 410522.8281828459
# inputs/medium79.in: cost 1535291.3171492692
# inputs/medium8.in: cost 2372034.8736800537
# inputs/medium80.in: cost 1885698.337169042
# inputs/medium81.in: cost 249822.8281828459
# inputs/medium82.in: cost 2379248.8736800537
# inputs/medium83.in: cost 304273.219127557
# inputs/medium84.in: cost 3.113945810299595e+20
# inputs/medium85.in: cost 381273.219127557
# inputs/medium86.in: cost 1160022.8281828458
# inputs/medium87.in: cost 1918603.190073396
# inputs/medium88.in: cost 2249242.828182846
# inputs/medium89.in: cost 600357.3371690421
# inputs/medium9.in: cost 2429252.2506811945
# inputs/medium90.in: cost 1185273.219127557
# inputs/medium91.in: cost 269540.8281828459
# inputs/medium92.in: cost 2993055.828182846
# inputs/medium93.in: cost 983460.8099124203
# inputs/medium94.in: cost 1470272.8281828458
# inputs/medium95.in: cost 3838341.996532662
# inputs/medium96.in: cost 16405617.876294352
# inputs/medium97.in: cost 560272.828182846
# inputs/medium98.in: cost 329426.8281828459
# inputs/medium99.in: cost 298272.8281828459
# inputs/small1.in: cost 1765145.337169042
# inputs/small10.in: cost 1171203.8281828458
# inputs/small100.in: cost 2451274.519281397
# inputs/small101.in: cost 1436500.9179587741
# inputs/small102.in: cost 1283903.1350622333
# inputs/small103.in: cost 300759.3371690421
# inputs/small104.in: cost 2443628.7708505495
# inputs/small105.in: cost 2431274.519281397
# inputs/small106.in: cost 246179.8281828459
# inputs/small107.in: cost 808274.5192813973
# inputs/small108.in: cost 389034.5192813973
# inputs/small109.in: cost 2475120.0200966783
# inputs/small11.in: cost 237272.8281828459
# inputs/small110.in: cost 2451274.519281397
# inputs/small111.in: cost 1379316.3171492692
# inputs/small112.in: cost 1165793.337169042
# inputs/small113.in: cost 1279655.7708505495
# inputs/small114.in: cost 2368197.828182846
# inputs/small115.in: cost 335274.12375063944
# inputs/small116.in: cost 350272.8281828459
# inputs/small117.in: cost 349924.5192813973
# inputs/small118.in: cost 1370947.6479950936
# inputs/small119.in: cost 2451274.519281397
# inputs/small12.in: cost 226017.51928139728
# inputs/small120.in: cost 2451274.519281397
# inputs/small121.in: cost 489272.8281828459
# inputs/small122.in: cost 294394.5192813973
# inputs/small123.in: cost 1224272.8281828458
# inputs/small124.in: cost 1637235.1350622333
# inputs/small125.in: cost 597927.828182846
# inputs/small126.in: cost 475260.91795877425
# inputs/small127.in: cost 1186017.0200966783
# inputs/small128.in: cost 1457205.337169042
# inputs/small129.in: cost 1968272.8281828458
# inputs/small13.in: cost 2033772.8281828458
# inputs/small130.in: cost 735418.5192813973
# inputs/small131.in: cost 474424.5192813973
# inputs/small132.in: cost 1422772.1350622333
# inputs/small133.in: cost 55059530.50115869
# inputs/small134.in: cost 1263815.6479950936
# inputs/small135.in: cost 1255953.9607293718
# inputs/small136.in: cost 301574.12375063944
# inputs/small137.in: cost 1058662.8281828458
# inputs/small138.in: cost 852271.3371690421
# inputs/small139.in: cost 783385.828182846
# inputs/small14.in: cost 255494.8281828459
# inputs/small140.in: cost 2226899.0200966783
# inputs/small141.in: cost 1296824.7708505495
# inputs/small142.in: cost 255864.8281828459
# inputs/small143.in: cost 623841.0200966783
# inputs/small144.in: cost 1674661.9607293718
# inputs/small145.in: cost 294576.3371690421
# inputs/small146.in: cost 475602.8281828459
# inputs/small147.in: cost 1097465.9179587744
# inputs/small148.in: cost 510272.8281828459
# inputs/small149.in: cost 334272.8281828459
# inputs/small15.in: cost 3059634.340944659
# inputs/small150.in: cost 1050203.1237506394
# inputs/small151.in: cost 1670822.4875981219
# inputs/small152.in: cost 238939.96072937187
# inputs/small153.in: cost 2451274.519281397
# inputs/small154.in: cost 445272.8281828459
# inputs/small155.in: cost 1095878.0200966783
# inputs/small156.in: cost 2079146.8281828458
# inputs/small157.in: cost 1144020.1237506394
# inputs/small158.in: cost 495274.5192813973
# inputs/small159.in: cost 317372.8281828459
# inputs/small16.in: cost 2451274.519281397
# inputs/small160.in: cost 445272.8281828459
# inputs/small161.in: cost 1818610.7708505495
# inputs/small162.in: cost 470272.8281828459
# inputs/small163.in: cost 2330920.7708505495
# inputs/small164.in: cost 1321498.9179587741
# inputs/small165.in: cost 1101971.1237506394
# inputs/small166.in: cost 8569387.047029685
# inputs/small167.in: cost 620219.1350622334
# inputs/small168.in: cost 8905054.047029685
# inputs/small169.in: cost 1683224.0200966783
# inputs/small17.in: cost 730629.1350622334
# inputs/small170.in: cost 839873.828182846
# inputs/small171.in: cost 4.33132645546241e+20
# inputs/small172.in: cost 903566.0200966783
# inputs/small173.in: cost 245483.8281828459
# inputs/small174.in: cost 1128840.1350622333
# inputs/small175.in: cost 1016430.828182846
# inputs/small176.in: cost 282282.8281828459
# inputs/small177.in: cost 374875.8281828459
# inputs/small178.in: cost 392635.91795877425
# inputs/small179.in: cost 2448574.519281397
# inputs/small18.in: cost 623818.1350622334
# inputs/small180.in: cost 277263.8281828459
# inputs/small181.in: cost 4.3313264554623985e+20
# inputs/small182.in: cost 1887019.337169042
# inputs/small183.in: cost 14594.519281397286
# inputs/small184.in: cost 1447180.8281828458
# inputs/small185.in: cost 367450.8281828459
# inputs/small186.in: cost 316625.3371690421
# inputs/small187.in: cost 1328252.1350622333
# inputs/small188.in: cost 2506160.135062233
# inputs/small189.in: cost 1378522.7708505495
# inputs/small19.in: cost 1779778.1237506394
# inputs/small190.in: cost 4955283.340944659
# inputs/small191.in: cost 1.1656026349855434e+21
# inputs/small192.in: cost 301072.8281828459
# inputs/small193.in: cost 282693.13506223337
# inputs/small194.in: cost 437108.13506223337
# inputs/small195.in: cost 1706715.1237506394
# inputs/small196.in: cost 1681926.0200966783
# inputs/small197.in: cost 1643815.0200966783
# inputs/small198.in: cost 2451274.519281397
# inputs/small199.in: cost 1327250.337169042
# inputs/small2.in: cost 2130547.0200966783
# inputs/small20.in: cost 1024842.9179587744
# inputs/small200.in: cost 1251657.1237506394
# inputs/small201.in: cost 2194334.7708505495
# inputs/small202.in: cost 2092975.9179587741
# inputs/small203.in: cost 2451274.519281397
# inputs/small204.in: cost 1354481.9607293718
# inputs/small205.in: cost 21685211.826390393
# inputs/small206.in: cost 7817054.047029685
# inputs/small207.in: cost 240707.8281828459
# inputs/small208.in: cost 854174.0200966783
# inputs/small209.in: cost 150720226406.74402
# inputs/small21.in: cost 244387.8281828459
# inputs/small210.in: cost 240757.8281828459
# inputs/small211.in: cost 261408.13506223334
# inputs/small212.in: cost 1847765.8281828458
# inputs/small213.in: cost 1583353.9179587741
# inputs/small214.in: cost 1449724.7708505495
# inputs/small215.in: cost 1461200.7708505495
# inputs/small216.in: cost 518672.8281828459
# inputs/small217.in: cost 2180302.7708505495
# inputs/small218.in: cost 551750.5192813973
# inputs/small219.in: cost 1809515.9179587741
# inputs/small22.in: cost 243020.8281828459
# inputs/small220.in: cost 684297.828182846
# inputs/small221.in: cost 1723863.0200966783
# inputs/small222.in: cost 2451274.519281397
# inputs/small223.in: cost 1903797.1237506394
# inputs/small224.in: cost 680792.9675001157
# inputs/small225.in: cost 242702.8281828459
# inputs/small226.in: cost 282272.8281828459
# inputs/small227.in: cost 1389816.337169042
# inputs/small228.in: cost 388590.91795877425
# inputs/small229.in: cost 206274.51928139728
# inputs/small23.in: cost 426850.8281828459
# inputs/small230.in: cost 276174.5192813973
# inputs/small231.in: cost 471252.5192813973
# inputs/small232.in: cost 281819.3371690421
# inputs/small233.in: cost 387691.91795877425
# inputs/small234.in: cost 2301048.337169042
# inputs/small235.in: cost 20812843363.52575
# inputs/small236.in: cost 655135.0200966783
# inputs/small237.in: cost 1229471.1350622333
# inputs/small238.in: cost 248019.8281828459
# inputs/small239.in: cost 266625.8281828459
# inputs/small24.in: cost 9065604.047029685
# inputs/small240.in: cost 1436502.337169042
# inputs/small241.in: cost 2257119.123750639
# inputs/small242.in: cost 2377808.7708505495
# inputs/small243.in: cost 2160872.828182846
# inputs/small244.in: cost 241565.8281828459
# inputs/small245.in: cost 303932.8281828459
# inputs/small246.in: cost 1.1656026349855433e+21
# inputs/small247.in: cost 4.33132645546238e+20
# inputs/small248.in: cost 1457895.337169042
# inputs/small249.in: cost 267272.8281828459
# inputs/small25.in: cost 510882.8281828459
# inputs/small250.in: cost 1395628.1237506394
# inputs/small251.in: cost 711814.0200966783
# inputs/small252.in: cost 1683071.0200966783
# inputs/small253.in: cost 1114028.1350622333
# inputs/small254.in: cost 265089.8281828459
# inputs/small255.in: cost 712821.3371690421
# inputs/small256.in: cost 1.1656026349855453e+21
# inputs/small257.in: cost 1399623.1237506394
# inputs/small258.in: cost 1.1656026349855453e+21
# inputs/small259.in: cost 448162.8281828459
# inputs/small26.in: cost 1322651.337169042
# inputs/small260.in: cost 1889230.4875981219
# inputs/small27.in: cost 1737951.1237506394
# inputs/small28.in: cost 1429733.9179587741
# inputs/small29.in: cost 1464145.337169042
# inputs/small3.in: cost 2450274.519281397
# inputs/small30.in: cost 1308462.8281828458
# inputs/small31.in: cost 388777.8281828459
# inputs/small32.in: cost 1086274.519281397
# inputs/small33.in: cost 2451274.519281397
# inputs/small34.in: cost 1638284.9607293718
# inputs/small35.in: cost 470453.13506223337
# inputs/small36.in: cost 2206174.519281397
# inputs/small37.in: cost 687693.1350622334
# inputs/small38.in: cost 1222480.1237506394
# inputs/small39.in: cost 249681.8281828459
# inputs/small4.in: cost 1259517.1237506394
# inputs/small40.in: cost 1115472.8281828458
# inputs/small41.in: cost 1225774.519281397
# inputs/small42.in: cost 1017522.1237506395
# inputs/small43.in: cost 2451274.519281397
# inputs/small44.in: cost 21728843.826390393
# inputs/small45.in: cost 1225774.519281397
# inputs/small46.in: cost 2450017.519281397
# inputs/small47.in: cost 450272.8281828459
# inputs/small48.in: cost 1692969.0200966783
# inputs/small49.in: cost 617926.5192813973
# inputs/small5.in: cost 299738.487598122
# inputs/small50.in: cost 588514.5192813973
# inputs/small51.in: cost 7873741.047029685
# inputs/small52.in: cost 1061955.4875981219
# inputs/small53.in: cost 1309274.519281397
# inputs/small54.in: cost 1218925.0200966783
# inputs/small55.in: cost 1261013.337169042
# inputs/small56.in: cost 57246281324572.82
# inputs/small57.in: cost 338819.3371690421
# inputs/small58.in: cost 279712.8281828459
# inputs/small59.in: cost 2451274.519281397
# inputs/small6.in: cost 282272.8281828459
# inputs/small60.in: cost 2451274.519281397
# inputs/small61.in: cost 3754228.340944659
# inputs/small62.in: cost 1232175.4875981219
# inputs/small63.in: cost 412965.91795877425
# inputs/small64.in: cost 450769.12375063944
# inputs/small65.in: cost 517478.3371690421
# inputs/small66.in: cost 2305274.519281397
# inputs/small67.in: cost 1837372.9607293718
# inputs/small68.in: cost 613565.3371690421
# inputs/small69.in: cost 1.165602634985544e+21
# inputs/small7.in: cost 2007191.9607293718
# inputs/small70.in: cost 214274.51928139728
# inputs/small71.in: cost 4802936.340944659
# inputs/small72.in: cost 325996.12375063944
# inputs/small73.in: cost 663440.828182846
# inputs/small74.in: cost 1496079.9179587741
# inputs/small75.in: cost 2451274.519281397
# inputs/small76.in: cost 1306243.337169042
# inputs/small77.in: cost 257349.8281828459
# inputs/small78.in: cost 1225774.519281397
# inputs/small79.in: cost 542674.1237506395
# inputs/small8.in: cost 1576174.0200966783
# inputs/small80.in: cost 21417765.826390393
# inputs/small81.in: cost 250276.51928139728
# inputs/small82.in: cost 1449135.337169042
# inputs/small83.in: cost 214274.51928139728
# inputs/small84.in: cost 3.068830528054149e+18
# inputs/small85.in: cost 313022.8281828459
# inputs/small86.in: cost 354470.8281828459
# inputs/small87.in: cost 448843.91795877425
# inputs/small88.in: cost 1047310.0200966783
# inputs/small89.in: cost 1063789.8281828458
# inputs/small9.in: cost 1387610.9607293718
# inputs/small90.in: cost 2451274.519281397
# inputs/small91.in: cost 252594.8281828459
# inputs/small92.in: cost 2082435.9179587741
# inputs/small93.in: cost 1158097.0200966783
# inputs/small94.in: cost 470272.8281828459
# inputs/small95.in: cost 1292376.337169042
# inputs/small96.in: cost 780347.0200966783
# inputs/small97.in: cost 529279.0701942592
# inputs/small98.in: cost 327397.8281828459
# inputs/small99.in: cost 288272.8281828459
